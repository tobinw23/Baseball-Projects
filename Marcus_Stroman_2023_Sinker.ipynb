# %% [markdown]
# <a href="https://colab.research.google.com/github/tobinw23/2023-baseball-project/blob/main/Marcus_Stroman_2023_Sinker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pybaseball

# %%
import pandas as pd
import numpy as np
import pybaseball as pyb
import matplotlib.pyplot as plt
import string
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg

# %%
from pybaseball import statcast_pitcher
from pybaseball import  playerid_lookup
from pybaseball import pitching_stats
pd.set_option('display.max_columns', None)
data = pitching_stats(2023)
data.head()
# Out:
#      IDfg  Season             Name Team  Age   W  L  WAR   ERA   G  GS  CG  \
# 19  10310    2023     Zack Wheeler  PHI   33  13  6  5.9  3.61  32  32   0
# 27  27498    2023  Spencer Strider  ATL   24  20  5  5.5  3.86  32  32   0
# 6   14107    2023    Kevin Gausman  TOR   32  12  9  5.3  3.16  31  31   0
# 2   12768    2023       Sonny Gray  MIN   33   8  8  5.3  2.79  32  32   0
# 15  19291    2023       Zac Gallen  ARI   27  17  9  5.2  3.47  34  34   1
#
#     ShO  SV  BS     IP  TBF    H   R  ER  HR  BB  IBB  HBP  WP  BK   SO   GB  \
# 19    0   0   0  192.0  787  168  82  77  20  39    0    9   1   0  212  216
# 27    0   0   0  186.2  763  146  85  80  22  58    1    9   6   2  281  141
# 6     0   0   0  185.0  763  163  72  65  19  55    0    3   3   2  237  197
# 2     0   0   0  184.0  754  156  59  57   8  55    0    6   6   1  183  239
# 15    1   0   0  210.0  846  188  87  81  22  47    0    5   8   1  220  239
#
# ...

# %%
data1 = pyb.statcast(start_dt='2023-03-30',end_dt='2023-06-30')
data2 = pyb.statcast(start_dt='2023-07-01',end_dt='2023-10-01')
data1.head(2)
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
# 100%|██████████| 93/93 [02:54<00:00,  1.88s/it]
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# ...

# %%
Stroman = data1.loc[data1['player_name'] == 'Stroman, Marcus']
Stroman1 = Stroman.loc[Stroman['pitch_type']=='SI']
Stroman1.head(2)
StromanA = data2.loc[data2['player_name'] == 'Stroman, Marcus']
Stroman2 =StromanA.loc[StromanA['pitch_type']=='SI']

# %%
min_plate_x = -0.83
max_plate_x = 0.83
min_plate_z = 1.17
max_plate_z = 3.92


strike_zone_width = max_plate_x - min_plate_x
strike_zone_height = max_plate_z - min_plate_z


strike_zone_center_x = (min_plate_x + max_plate_x) / 2
strike_zone_center_z = (min_plate_z + max_plate_z) / 2


print("Strike zone coordinates:")
print(f"  Bottom-left: ({min_plate_x}, {min_plate_z})")
print(f"  Top-right: ({max_plate_x}, {max_plate_z})")
print(f"  Center: ({strike_zone_center_x}, {strike_zone_center_z})")
# Out:
# Strike zone coordinates:
#   Bottom-left: (-0.83, 1.17)
#   Top-right: (0.83, 3.92)
#   Center: (0.0, 2.545)

# %%
import matplotlib.patches as patches
import seaborn as sns
rect = patches.Rectangle(
    (-0.83, 1.17),
    1.66,
    2.75,
    linewidth=1,
    edgecolor='black',
    facecolor='none'
)


sns.relplot(
    data=Stroman1,
    x="plate_x",
    y="plate_z",
    hue="bb_type",
    aspect=1,
)

ax = plt.gca()

ax.add_patch(rect)



ax.set_xlim(-1.5, 1.5)
ax.set_ylim(1, 4)

ax.set_title("Marcus Stroman's Sinker in 1st Half 2023")
ax.set_xlabel("Plate X")
ax.set_ylabel("Plate Z")
plt.show()

rect = patches.Rectangle(
    (-0.83, 1.17),
    1.66,
    2.75,
    linewidth=1,
    edgecolor='black',
    facecolor='none'
)


sns.relplot(
    data=Stroman2,
    x="plate_x",
    y="plate_z",
    hue="bb_type",
    aspect=1,
)

ax = plt.gca()

ax.add_patch(rect)


ax.set_title("Marcus Stroman's Sinker in 2nd Half 2023")

ax.set_xlim(-1.5, 1.5)
ax.set_ylim(1, 4)

ax.set_xlabel("Plate X")
ax.set_ylabel("Plate Z")
plt.show()
